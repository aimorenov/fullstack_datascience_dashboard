# %% [markdown]
# # Exploratory data analysis
# In this notebook I explored the get_around_delay_analysis data to define the distribution of different variables and identify which variables would aide the most in answering the following questions:
# - What is the best minimun delay between two rentals  (threshold)
# - What is the scope of such new feature: mobile vs connect rentals
# - What is the frequency of drivers being late and the impact on the next driver (rental canceled or not)

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import os

# %%
# Define current dir (needed for when deploying app in Heroku)
curren_dir = os.getcwd()
curren_dir
# Out:
# '/Users/aura.moreno/Documents/Jedha/fullstack_datascience/05-Getaround_app_deployment/dashboard'

# %% [markdown]
# ## Load data

# %%
# Load data
file_name = os.path.join(curren_dir,'data/raw/get_around_delay_analysis.xlsx')

df = pd.read_excel(io = file_name,engine=None,sheet_name='rentals_data')
print("Shape of delay data:",df.shape)
df.head()
# Out:
# Shape of delay data: (21310, 7)
#    rental_id    car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0   505000.0  363965.0       mobile  canceled                           NaN
# 1   507750.0  269550.0       mobile     ended                         -81.0
# 2   508131.0  359049.0      connect     ended                          70.0
# 3   508865.0  299063.0      connect  canceled                           NaN
# 4   511440.0  313932.0       mobile     ended                           NaN
#
#    previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# 0                       NaN                                         NaN
# 1                       NaN                                         NaN
# 2                       NaN                                         NaN
# 3                       NaN                                         NaN
# 4                       NaN                                         NaN

# %%
# Info on data variables and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21310 entries, 0 to 21309
# Data columns (total 7 columns):
#  #   Column                                      Non-Null Count  Dtype
# ---  ------                                      --------------  -----
#  0   rental_id                                   21310 non-null  float64
#  1   car_id                                      21310 non-null  float64
#  2   checkin_type                                21310 non-null  object
#  3   state                                       21310 non-null  object
#  4   delay_at_checkout_in_minutes                16346 non-null  float64
#  5   previous_ended_rental_id                    1841 non-null   float64
#  6   time_delta_with_previous_rental_in_minutes  1841 non-null   float64
# dtypes: float64(5), object(2)
# memory usage: 1.1+ MB

# %%
# Convert rental_id, car_id and previous_ended_rental_id to string
df['rental_id'] = [str(i) for i in df.rental_id.tolist()]
df['car_id'] = [str(i) for i in df.car_id.tolist()]
df['previous_ended_rental_id'] = [str(i) for i in df.previous_ended_rental_id.tolist()]

# %%
# Basic description
df.describe(include='all')
# Out:
#        rental_id    car_id checkin_type  state  delay_at_checkout_in_minutes  \
# count      21310     21310        21310  21310                  16346.000000
# unique     21310      8143            2      2                           NaN
# top     505000.0  334190.0       mobile  ended                           NaN
# freq           1        33        17003  18045                           NaN
# mean         NaN       NaN          NaN    NaN                     59.701517
# std          NaN       NaN          NaN    NaN                   1002.561635
# min          NaN       NaN          NaN    NaN                 -22433.000000
# 25%          NaN       NaN          NaN    NaN                    -36.000000
# 50%          NaN       NaN          NaN    NaN                      9.000000
# 75%          NaN       NaN          NaN    NaN                     67.000000
# max          NaN       NaN          NaN    NaN                  71084.000000
#
#        previous_ended_rental_id  time_delta_with_previous_rental_in_minutes
# count                     21310                                 1841.000000
# unique                     1789                                         NaN
# top                         nan                                         NaN
# freq                      19469                                         NaN
# mean                        NaN                                  279.288430
# std                         NaN                                  254.594486
# min                         NaN                                    0.000000
# 25%                         NaN                                   60.000000
# 50%                         NaN                                  180.000000
# 75%                         NaN                                  540.000000
# max                         NaN                                  720.000000

# %% [markdown]
# We see that we have some very extreme values for the delay at checkout in minutes.
# Show this as a plot, and then filter out such extreme values

# %% [markdown]
# In order to have straight away the info on whether if the cancelled rental had a previous late check in, create a second dataframe

# %%
# Add column to indicate if rental checkin late
df['checkout_late'] = ['late' if delay>0  else 'early' if delay<0 else 'notapplicable' for delay in df.delay_at_checkout_in_minutes]
df.checkout_late.value_counts()
# Out:
# late             9404
# early            6820
# notapplicable    5086
# Name: checkout_late, dtype: int64

# %%
# Dataframe giving information for previously ended rental
df_2 = df.copy()
df_2 = df[['rental_id', 'car_id','checkin_type','checkout_late', 'delay_at_checkout_in_minutes']]
df_2 = df_2.rename(columns={'rental_id':'previous_ended_rental_id', 'checkout_late':'previous_ended_rental_late', 'delay_at_checkout_in_minutes':'previous_ended_rental_checkout_delay'})
print(df_2.shape)
df_2.head()
# Out:
# (21310, 5)
#   previous_ended_rental_id    car_id checkin_type previous_ended_rental_late  \
# 0                 505000.0  363965.0       mobile              notapplicable
# 1                 507750.0  269550.0       mobile                      early
# 2                 508131.0  359049.0      connect                       late
# 3                 508865.0  299063.0      connect              notapplicable
# 4                 511440.0  313932.0       mobile              notapplicable
#
#    previous_ended_rental_checkout_delay
# 0                                   NaN
# 1                                 -81.0
# 2                                  70.0
# 3                                   NaN
# 4                                   NaN

# %%
# Merged dataframes
df_merged = df.merge(df_2,how="left")
print(df_merged.shape)
df_merged.head(20)
# Out:
# (21310, 10)
#    rental_id    car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0   505000.0  363965.0       mobile  canceled                           NaN
# 1   507750.0  269550.0       mobile     ended                         -81.0
# 2   508131.0  359049.0      connect     ended                          70.0
# 3   508865.0  299063.0      connect  canceled                           NaN
# 4   511440.0  313932.0       mobile     ended                           NaN
# 5   511626.0  398802.0       mobile     ended                        -203.0
# 6   511639.0  370585.0      connect     ended                         -15.0
# 7   512303.0  371242.0       mobile     ended                         -44.0
# 8   512475.0  322502.0       mobile  canceled                           NaN
# 9   513434.0  256528.0      connect     ended                          23.0
# 10  513743.0  330658.0       mobile  canceled                           NaN
# 11  514161.0  366037.0      connect  canceled                           NaN
# 12  514257.0  402596.0       mobile     ended                         214.0
# 13  515147.0  257466.0       mobile     ended                          15.0
# 14  516586.0  347394.0       mobile  canceled                           NaN
# 15  518282.0  364160.0      connect     ended                         -81.0
# 16  518366.0  397217.0       mobile     ended                        -156.0
# 17  518895.0  398816.0       mobile     ended                          66.0
# 18  518938.0  382243.0       mobile     ended                         215.0
# 19  519491.0  312389.0       mobile     ended                          58.0
#
#    previous_ended_rental_id  time_delta_with_previous_rental_in_minutes  \
# 0                       nan                                         NaN
# 1                       nan                                         NaN
# 2                       nan                                         NaN
# 3                       nan                                         NaN
# 4                       nan                                         NaN
# 5                       nan                                         NaN
# 6                  563782.0                                       570.0
# 7                       nan                                         NaN
# 8                       nan                                         NaN
# 9                       nan                                         NaN
# 10                      nan                                         NaN
# 11                      nan                                         NaN
# 12                      nan                                         NaN
# 13                      nan                                         NaN
# 14                      nan                                         NaN
# 15                      nan                                         NaN
# 16                      nan                                         NaN
# 17                      nan                                         NaN
# 18                      nan                                         NaN
# 19                 545639.0                                       420.0
#
#     checkout_late previous_ended_rental_late  \
# 0   notapplicable                        NaN
# 1           early                        NaN
# 2            late                        NaN
# 3   notapplicable                        NaN
# 4   notapplicable                        NaN
# 5           early                        NaN
# 6           early                       late
# 7           early                        NaN
# 8   notapplicable                        NaN
# 9            late                        NaN
# 10  notapplicable                        NaN
# 11  notapplicable                        NaN
# 12           late                        NaN
# 13           late                        NaN
# 14  notapplicable                        NaN
# 15          early                        NaN
# 16          early                        NaN
# 17           late                        NaN
# 18           late                        NaN
# 19           late                       late
#
#     previous_ended_rental_checkout_delay
# 0                                    NaN
# 1                                    NaN
# 2                                    NaN
# 3                                    NaN
# 4                                    NaN
# 5                                    NaN
# 6                                  136.0
# 7                                    NaN
# 8                                    NaN
# 9                                    NaN
# 10                                   NaN
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                   NaN
# 16                                   NaN
# 17                                   NaN
# 18                                   NaN
# 19                                 140.0

# %%
# Add a column indicating  delta between chechekin delay and time delta between chained rentals
df_merged['delta_checkin_previous_rental'] = df_merged.time_delta_with_previous_rental_in_minutes - df_merged.previous_ended_rental_checkout_delay
df_merged['delta_checkin_previous_rental'].describe()
# Out:
# count     1714.000000
# mean       300.679697
# std        496.907112
# min     -12548.000000
# 25%         48.000000
# 50%        201.500000
# 75%        574.000000
# max       4684.000000
# Name: delta_checkin_previous_rental, dtype: float64

# %%
# Boolean column for problematic cases
df_merged['delta_checkin_previous_rental_problematic_bool'] = ['yes' if delay<0 else 'no' for delay in df_merged.delta_checkin_previous_rental.tolist()]

# %%
# Add column indicating if rental is being succeceded in less than 12 hours
df_merged['succesive_rental'] = ['yes' if float(rental)>0 else 'no' for rental in df_merged.previous_ended_rental_id.tolist()]
df_merged['succesive_rental'].value_counts()
# Out:
# no     19469
# yes     1841
# Name: succesive_rental, dtype: int64

# %%
df_merged.head(10)
# Out:
#   rental_id    car_id checkin_type     state  delay_at_checkout_in_minutes  \
# 0  505000.0  363965.0       mobile  canceled                           NaN
# 1  507750.0  269550.0       mobile     ended                         -81.0
# 2  508131.0  359049.0      connect     ended                          70.0
# 3  508865.0  299063.0      connect  canceled                           NaN
# 4  511440.0  313932.0       mobile     ended                           NaN
# 5  511626.0  398802.0       mobile     ended                        -203.0
# 6  511639.0  370585.0      connect     ended                         -15.0
# 7  512303.0  371242.0       mobile     ended                         -44.0
# 8  512475.0  322502.0       mobile  canceled                           NaN
# 9  513434.0  256528.0      connect     ended                          23.0
#
#   previous_ended_rental_id  time_delta_with_previous_rental_in_minutes  \
# 0                      nan                                         NaN
# 1                      nan                                         NaN
# 2                      nan                                         NaN
# 3                      nan                                         NaN
# 4                      nan                                         NaN
# 5                      nan                                         NaN
# 6                 563782.0                                       570.0
# 7                      nan                                         NaN
# 8                      nan                                         NaN
# 9                      nan                                         NaN
#
#    checkout_late previous_ended_rental_late  \
# 0  notapplicable                        NaN
# 1          early                        NaN
# 2           late                        NaN
# 3  notapplicable                        NaN
# 4  notapplicable                        NaN
# 5          early                        NaN
# 6          early                       late
# 7          early                        NaN
# 8  notapplicable                        NaN
# 9           late                        NaN
#
#    previous_ended_rental_checkout_delay  delta_checkin_previous_rental  \
# 0                                   NaN                            NaN
# 1                                   NaN                            NaN
# 2                                   NaN                            NaN
# 3                                   NaN                            NaN
# 4                                   NaN                            NaN
# 5                                   NaN                            NaN
# 6                                 136.0                          434.0
# 7                                   NaN                            NaN
# 8                                   NaN                            NaN
# 9                                   NaN                            NaN
#
#   delta_checkin_previous_rental_problematic_bool succesive_rental
# 0                                             no               no
# 1                                             no               no
# 2                                             no               no
# 3                                             no               no
# 4                                             no               no
# 5                                             no               no
# 6                                             no              yes
# 7                                             no               no
# 8                                             no               no
# 9                                             no               no

# %% [markdown]
# ## Export dataframe for plotting

# %%
file_name = os.path.join(curren_dir,'data/processed/get_around_delay_analysis.csv')
df_merged.to_csv(file_name, index=False)

# %% [markdown]
# ## Plots

# %%
# Total of ended rentals being late
dfg = df_merged.groupby(['checkout_late']).size().reset_index(name='counts')
dfg['proportion_of_total_rentals'] = dfg.counts / sum(dfg.counts)
print(sum(dfg.counts))
display(dfg)

fig = px.bar(dfg, x="checkout_late", y ='proportion_of_total_rentals', 
title=" Fig1. Check-out late status of all rentals (n ={} rentals; {} successive rentals)".format(sum(dfg.counts), df_merged.succesive_rental.value_counts()['yes']))
fig.show(renderer='notebook_connected')
# Out:
# 21310
#    checkout_late  counts  proportion_of_total_rentals
# 0          early    6820                     0.320038
# 1           late    9404                     0.441295
# 2  notapplicable    5086                     0.238667
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="2f9533be-a6c5-4e6b-b14a-d23f2c1fcfbc" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2f9533be-a6c5-4e6b-b14a-d23f2c1fcfbc")) {                    Plotly.newPlot(                        "2f9533be-a6c5-4e6b-b14a-d23f2c1fcfbc",                        [{"alignmentgroup":"True","hovertemplate":"checkout_late=%{x}<br>proportion_of_total_rentals=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["early","late","notapplicable"],"xaxis":"x","y":[0.32003754106053495,0.44129516658845613,0.23866729235100892],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks ...

# %%
# Total of ended rentals being late
dfg = df_merged.groupby(['checkin_type','checkout_late']).size().reset_index(name='counts')
print(sum(dfg.counts))
display(dfg)

tot_rentals_mobile = df_merged.checkin_type.value_counts()['mobile']
tot_rentals_connect = df_merged.checkin_type.value_counts()['connect']

fig = px.histogram(df_merged, x="checkin_type", barmode='group',barnorm='percent', color="checkout_late",color_discrete_sequence=px.colors.qualitative.D3,
title="Fig2.Check-out late status of all rentals (n ={} mobile rentals; n = {} connect rentals)".format(tot_rentals_mobile, tot_rentals_connect))
fig.show(renderer='notebook_connected')
# Out:
# 21310
#   checkin_type  checkout_late  counts
# 0      connect          early    1918
# 1      connect           late    1459
# 2      connect  notapplicable     930
# 3       mobile          early    4902
# 4       mobile           late    7945
# 5       mobile  notapplicable    4156
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="616fb552-e894-463d-b0d2-d6c5469df420" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("616fb552-e894-463d-b0d2-d6c5469df420")) {                    Plotly.newPlot(                        "616fb552-e894-463d-b0d2-d6c5469df420",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"checkout_late=notapplicable<br>checkin_type=%{x}<br>count (normalized as percent)=%{y}<extra></extra>","legendgroup":"notapplicable","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"notapplicable","offsetgroup":"notapplicable","orientation":"v","showlegend":true,"x":["mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile", ...

# %%
# Total of succeded rentals per application
dfg = df_merged.groupby(['checkin_type', 'succesive_rental']).size().reset_index(name='counts')
display(dfg)

suc_rentals_mob = dfg.counts[(dfg.succesive_rental=='yes') & (dfg.checkin_type=="mobile")].values[0]
suc_rentals_conn = dfg.counts[ (dfg.succesive_rental=='yes') & (dfg.checkin_type=="connect")].values[0]

fig = px.histogram(df_merged, x="checkin_type", barmode='group',barnorm='percent', color="succesive_rental",color_discrete_sequence=px.colors.qualitative.Safe,
title= f'Fig3.Successive rentals proportion (n= {suc_rentals_mob} and {suc_rentals_conn} successive rentals for mobile and connect respectively)')
fig.show(renderer='notebook_connected')
# Out:
#   checkin_type succesive_rental  counts
# 0      connect               no    3494
# 1      connect              yes     813
# 2       mobile               no   15975
# 3       mobile              yes    1028
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="87a4c003-a46d-4e72-bccd-355fc0d71435" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87a4c003-a46d-4e72-bccd-355fc0d71435")) {                    Plotly.newPlot(                        "87a4c003-a46d-4e72-bccd-355fc0d71435",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"succesive_rental=no<br>checkin_type=%{x}<br>count (normalized as percent)=%{y}<extra></extra>","legendgroup":"no","marker":{"color":"rgb(136, 204, 238)","pattern":{"shape":""}},"name":"no","offsetgroup":"no","orientation":"v","showlegend":true,"x":["mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","connect","mobile","mobile","connect","mobile","mobile","mobile","connect","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","mob ...

# %%
# Distribution of delay at checkout

delay_quantile = df_merged['delay_at_checkout_in_minutes'].quantile((0,0.25,0.5,0.75,1))
print(delay_quantile)

print('Fifty percent of rentals have a delay checkin time between {} and {} minutes'.format(
    delay_quantile.loc[0.25],delay_quantile.loc[0.75] )
    )


fig = px.histogram(df_merged, x="delay_at_checkout_in_minutes", nbins=200, marginal="box", title='Fig4.Distribution of delay at checkout',
labels={'delay_at_checkout_in_minutes': 'Delay at chekout (mins)'

})
fig.show(renderer='notebook_connected')
# Out:
# 0.00   -22433.0
# 0.25      -36.0
# 0.50        9.0
# 0.75       67.0
# 1.00    71084.0
# Name: delay_at_checkout_in_minutes, dtype: float64
# Fifty percent of rentals have a delay checkin time between -36.0 and 67.0 minutes
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1ca2c00f-dfa2-4041-ac7d-9ab709f410d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ca2c00f-dfa2-4041-ac7d-9ab709f410d8")) {                    Plotly.newPlot(                        "1ca2c00f-dfa2-4041-ac7d-9ab709f410d8",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Delay at chekout (mins)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":200,"offsetgroup":"","orientation":"v","showlegend":false,"x":[null,-81.0,70.0,null,null,-203.0,-15.0,-44.0,null,23.0,null,null,214.0,15.0,null,-81.0,-156.0,66.0,215.0,58.0,-159.0,-16.0,null,null,1452.0,-29.0,null,-251.0,35.0,null,-345.0,null,null,-26.0,null,22.0,-15.0,52.0,-2.0,-1.0,-76.0,null,null,15.0,null,null,null,-68.0,-340.0,130.0,29.0,-4.0,-160.0,-30.0,-47.0,-63.0,-148.0,44.0,-98.0,-33.0,-340.0,-167.0,31.0,null,-6.0,79.0,null,30.0,null,null,33.0,-52.0,44.0,-576.0,-7.0,null,-178.0,37.0,24.0,40.0,137.0,249.0,23.0,-108.0,-6.0,-150.0,9.0,68.0,38.0,-1.0,74.0,-10.0,-843.0,null,780.0,-130.0,null,271.0,-12.0,933.0,null,null,1967.0,-125.0,-96.0,205.0,null,18.0,48.0,266.0,36.0,null,-35.0,80.0,3233.0,-24.0,-129.0,2.0,-37.0,8.0,-155.0,134.0,-15.0,13.0,-348.0,-120.0,85.0,-35.0,66.0,null,32.0,41.0,3.0,-536.0,null,216.0,null,28.0,-51.0,93.0,-196.0,9.0,-988.0,-6.0,-18.0,null,-62.0,210.0,12.0,-24.0,-5.0,null,90.0,15422.0,-14.0,11.0,-7.0,146.0,-25.0,null,13.0,901.0,null,52.0,125.0,null,165.0,-25.0,null,null,83.0,69.0,156.0,null,null,12.0,50.0,-7.0,null,183.0,null,-170.0,-36.0,-106.0,9.0,-21.0,64.0,23.0,14.0,5.0,300.0,-18.0,null,12.0,48.0,-9.0,-57.0,-529.0,670.0,-1087.0,-53.0,64.0,2.0,24.0,null,55.0,75.0,null,null,-44.0,-244.0,337.0,39.0,56.0,null,31.0,-23.0,null,233.0,50.0,108.0,56.0,-2.0,74.0,-31.0,7.0,null,302.0,-98.0,93.0,20.0,null,null,-467
df_merged_clean = df_merged[~mask_12hrs]
print('Data shape after filter:',df_merged.shape)
# Out:
# Data shape before filter: (21310, 13)
# Data shape after filter: (21310, 13)

# %%
# Distribution of delay at checkout: Focus on delays of  4 hours
df_merged_filt = df_merged.copy()
delay_hours = 4
filter_mask = abs(df_merged_filt['delay_at_checkout_in_minutes']) <= delay_hours*60
df_merged_filt = df_merged_filt[filter_mask]

fig = px.histogram(df_merged_filt, x="delay_at_checkout_in_minutes", marginal="box",
nbins=200, title=f'Fig5.Distribution of delay at checkout (max {delay_hours}hrs absolute)', 
labels={'delay_at_checkout_in_minutes': 'Delay at chekout (mins)'

})


fig.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e408c18a-dbcd-425f-a0f8-6d0455248b49" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e408c18a-dbcd-425f-a0f8-6d0455248b49")) {                    Plotly.newPlot(                        "e408c18a-dbcd-425f-a0f8-6d0455248b49",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Delay at chekout (mins)=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","nbinsx":200,"offsetgroup":"","orientation":"v","showlegend":false,"x":[-81.0,70.0,-203.0,-15.0,-44.0,23.0,214.0,15.0,-81.0,-156.0,66.0,215.0,58.0,-159.0,-16.0,-29.0,35.0,-26.0,22.0,-15.0,52.0,-2.0,-1.0,-76.0,15.0,-68.0,130.0,29.0,-4.0,-160.0,-30.0,-47.0,-63.0,-148.0,44.0,-98.0,-33.0,-167.0,31.0,-6.0,79.0,30.0,33.0,-52.0,44.0,-7.0,-178.0,37.0,24.0,40.0,137.0,23.0,-108.0,-6.0,-150.0,9.0,68.0,38.0,-1.0,74.0,-10.0,-130.0,-12.0,-125.0,-96.0,205.0,18.0,48.0,36.0,-35.0,80.0,-24.0,-129.0,2.0,-37.0,8.0,-155.0,134.0,-15.0,13.0,-120.0,85.0,-35.0,66.0,32.0,41.0,3.0,216.0,28.0,-51.0,93.0,-196.0,9.0,-6.0,-18.0,-62.0,210.0,12.0,-24.0,-5.0,90.0,-14.0,11.0,-7.0,146.0,-25.0,13.0,52.0,125.0,165.0,-25.0,83.0,69.0,156.0,12.0,50.0,-7.0,183.0,-170.0,-36.0,-106.0,9.0,-21.0,64.0,23.0,14.0,5.0,-18.0,12.0,48.0,-9.0,-57.0,-53.0,64.0,2.0,24.0,55.0,75.0,-44.0,39.0,56.0,31.0,-23.0,233.0,50.0,108.0,56.0,-2.0,74.0,-31.0,7.0,-98.0,93.0,20.0,20.0,69.0,-9.0,-80.0,-44.0,163.0,-2.0,10.0,-52.0,16.0,92.0,7.0,-55.0,30.0,84.0,85.0,10.0,-113.0,-5.0,1.0,145.0,8.0,-8.0,74.0,126.0,15.0,-8.0,195.0,-133.0,-22.0,201.0,21.0,-40.0,225.0,-37.0,-12.0,-11.0,-26.0,-49.0,22.0,144.0,69.0,19.0,10.0,-5.0,-127.0,-158.0,54.0,3.0,201.0,167.0,-136.0,-158.0,20.0,-7.0,-15.0,-127.0,82.0,37.0,0.0,-41.0,-25.0,40.0,-22.0,211.0,97.0,16.0,159.0,-7.0,34.0,203.0,-193.0,11.0,91.0,23.0,4.0,-28.0,23.0,6.0,-102.0,-232.0,-22.0,31.0,63.0,10.0,40.0,20.0,5.0,7.0,-1.0,24.0,170.0,-20.0,-3.0,-36.0,-29.0,1.0,11.0,-148.0,37.0,-37.0,-5.0,17.0,-72.0,161.0,146.0,-
.0,42.0,34.0,6.0,4.0,12.0,42.0,9.0,25.0,10.0,2.0,96.0,9.0,87.0,7.0,26.0,8.0,58.0,104.0,15.0,208.0,1.0,89.0,10.0,182.0,6.0,126.0,73.0,8.0,44.0,124.0,8.0,78.0,49.0,97.0,20.0,76.0,48.0,31.0,62.0,60.0,203.0,35.0,62.0,4.0,21.0,4.0,57.0,38.0,38.0,25.0,151.0,28.0,16.0,29.0,3.0,11.0,16.0,11.0,66.0,235.0,48.0,186.0,38.0,58.0,41.0,28.0,38.0,22.0,7.0,88.0,54.0,33.0,8.0,217.0,67.0,101.0,43.0,128.0,72.0,108.0,131.0,71.0,225.0,6.0,8.0,2.0,2.0,4.0,12.0,51.0,19.0,13.0,41.0,12.0,240.0,7.0,27.0,6.0,54.0,8.0,8.0,69.0,10.0,2.0,5.0,3.0,27.0,60.0,92.0,124.0,51.0,102.0,16.0,56.0,28.0,11.0,2.0,50.0,50.0,14.0,41.0,194.0,106.0,1.0,99.0,51.0,194.0,236.0,6.0,130.0,7.0,55.0,15.0,28.0,14.0,7.0,42.0,69.0,116.0,64.0,23.0,102.0,78.0,6.0,72.0,12.0,49.0,14.0,5.0,103.0,13.0,40.0,29.0,20.0,153.0,92.0,8.0,12.0,55.0,76.0,77.0,5.0,6.0,23.0,39.0,79.0,73.0,29.0,18.0,205.0,96.0,64.0,13.0,205.0,20.0,4.0,103.0,36.0,4.0,122.0,13.0,20.0,33.0,37.0,58.0,126.0,5.0,85.0,9.0,101.0,6.0,26.0,31.0,82.0,37.0,72.0,89.0,13.0,11.0,167.0,4.0,16.0,19.0,146.0,71.0,22.0,136.0,78.0,49.0,15.0,26.0,187.0,27.0,131.0,65.0,14.0,96.0,137.0,15.0,128.0,209.0,63.0,1.0,7.0,74.0,5.0,128.0,11.0,69.0,14.0,137.0,144.0,22.0,88.0,9.0,121.0,109.0,26.0,34.0,95.0,31.0,175.0,28.0,17.0,14.0,37.0,67.0,42.0,86.0,88.0,89.0,18.0,96.0,166.0,228.0,48.0,14.0,7.0,29.0,9.0,31.0,38.0,9.0,40.0,5.0,115.0,21.0,18.0,148.0,4.0,155.0,139.0,47.0,91.0,227.0,11.0,180.0,90.0,2.0,5.0,34.0,79.0,68.0,172.0,57.0,136.0,14.0,37.0,14.0,98.0,36.0,86.0,3.0,35.0,155.0,28.0,65. ...

# %%
# Frequency of being late, and impact on next driver: take a look at if previous rental was late, and whether the state of actual rental

dfg = df_merged.groupby(['previous_ended_rental_late', 'state']).size().reset_index(name='counts')
print(sum(dfg.counts))
display(dfg)


fig = px.histogram(df_merged, x="previous_ended_rental_late", barmode='group',barnorm='percent', color="state",
title="Fig7.Cancelled and ended status for different delay categories")
fig.show(renderer='notebook_connected')
# Out:
# 1824
#   previous_ended_rental_late     state  counts
# 0                      early  canceled     100
# 1                      early     ended     734
# 2                       late  canceled     105
# 3                       late     ended     759
# 4              notapplicable  canceled      22
# 5              notapplicable     ended     104
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="e5e54c47-14c5-4331-8147-78bb9ca1232f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e5e54c47-14c5-4331-8147-78bb9ca1232f")) {                    Plotly.newPlot(                        "e5e54c47-14c5-4331-8147-78bb9ca1232f",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=canceled<br>previous_ended_rental_late=%{x}<br>count (normalized as percent)=%{y}<extra></extra>","legendgroup":"canceled","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"canceled","offsetgroup":"canceled","orientation":"v","showlegend":true,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,"early",null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,"late","early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,"early",null,null,null,"late","early",null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,"early",null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,nul ...

# %%
# Separate by mobile app
dfg = df_merged.groupby(['previous_ended_rental_late', 'checkin_type', 'state']).size().reset_index(name='counts')
print(sum(dfg.counts))
display(dfg)


fig = px.histogram(df_merged, x="previous_ended_rental_late", facet_col="checkin_type",barmode='group', color="state",
title="Fig8.Cancelled and ended status for different delay categories")
fig.show(renderer='notebook_connected')
# Out:
# 1824
#    previous_ended_rental_late checkin_type     state  counts
# 0                       early      connect  canceled      66
# 1                       early      connect     ended     409
# 2                       early       mobile  canceled      34
# 3                       early       mobile     ended     325
# 4                        late      connect  canceled      55
# 5                        late      connect     ended     242
# 6                        late       mobile  canceled      50
# 7                        late       mobile     ended     517
# 8               notapplicable      connect  canceled       9
# 9               notapplicable      connect     ended      20
# 10              notapplicable       mobile  canceled      13
# 11              notapplicable       mobile     ended      84
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="d11f594b-0055-451b-8264-7da572c07c3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d11f594b-0055-451b-8264-7da572c07c3a")) {                    Plotly.newPlot(                        "d11f594b-0055-451b-8264-7da572c07c3a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=canceled<br>checkin_type=mobile<br>previous_ended_rental_late=%{x}<br>count=%{y}<extra></extra>","legendgroup":"canceled","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"canceled","offsetgroup":"canceled","orientation":"v","showlegend":true,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,"late",null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late","late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null ...

# %%
# Show proportions
fig = px.histogram(df_merged, x="previous_ended_rental_late", facet_col="checkin_type",barmode='group',barnorm='percent', color="state",
title="Fig9.Cancelled and ended status for different delay categories: proportions")
fig.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="cc246d73-a1f3-4cb8-8c31-9295ad418d7a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc246d73-a1f3-4cb8-8c31-9295ad418d7a")) {                    Plotly.newPlot(                        "cc246d73-a1f3-4cb8-8c31-9295ad418d7a",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"state=canceled<br>checkin_type=mobile<br>previous_ended_rental_late=%{x}<br>count (normalized as percent)=%{y}<extra></extra>","legendgroup":"canceled","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"canceled","offsetgroup":"canceled","orientation":"v","showlegend":true,"x":[null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,"late",null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"notapplicable",null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"late","late",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,"early",null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null, ...

# %% [markdown]
# #### Focus on successive rentals

# %%
# Proportion of problematic delays with respect to time beween chekcout and checkin and cancelled status

df_merged_filt = df_merged.copy()
filter_mask = df_merged.succesive_rental=="yes"
df_merged_filt = df_merged_filt[filter_mask]

dfg = df_merged_filt.groupby(['delta_checkin_previous_rental_problematic_bool']).size().reset_index(name='counts')
print(sum(dfg.counts))
display(dfg)


fig = px.histogram(df_merged_filt, x="checkin_type", barmode='group', color="delta_checkin_previous_rental_problematic_bool",
title="Fig10.Impact of late check-in on next rental", 
labels={'delta_checkin_previous_rental_problematic_bool': 'problematic late checkin',
'checkin_type': 'Check-in type'})
fig.show(renderer='notebook_connected')
# Out:
# 1841
#   delta_checkin_previous_rental_problematic_bool  counts
# 0                                             no    1623
# 1                                            yes     218
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="a588d1fd-9bfa-4b65-b63c-d3580c885e64" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a588d1fd-9bfa-4b65-b63c-d3580c885e64")) {                    Plotly.newPlot(                        "a588d1fd-9bfa-4b65-b63c-d3580c885e64",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"problematic late checkin=no<br>Check-in type=%{x}<br>count=%{y}<extra></extra>","legendgroup":"no","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"no","offsetgroup":"no","orientation":"v","showlegend":true,"x":["connect","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","connect","connect","mobile","connect","mobile","mobile","mobile","connect","connect","connect","connect","mobile","connect","connect","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","connect","connect","mobile","connect","connect","connect","mobile","connect","connect","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","connect","connect","connect","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","connect","mobile","mobile","connect","mobile","mobile","connect","connect","mobile","mobile","connect","mobile","mobile","connect","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","mobile","connect","connect","connect","connect","mobile","connect","connect","mobile","connect","mobile","mobile","mobile","connect","mobile","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","connect","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","connect","connect","mobile","mobile","mobile","connect","connect","connect","connect","mobile","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","mobile","mobile","mobile","mobile","connect","connect","connect","mobile","connect","connect","mobile","mobile","connect","mobile","mobile","connect","connect","connect","mobile","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","connect","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","connect","mobile","connect","mobile","connect","mobile","connect","connect","connect","mobile","connect","mobile","mobile","mobile","mobile","connect","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","connect","connect","mobile","connect","mobile","mobile","mobile","mobile","connect","connect","mobile","mobile","mobile","mobile","connect","mobile","connect","mobile","connect","connect","connect","mobile","mobile","mobile","connect","connect","connect","mobile","connect","mobile","mobile","mobile","connect","connect","connect","mobile","connect","mobile","connect","mobile","connect","mobile","connect","connect","mobile","connect","mobile","connect","mobile","mobile","connect","connect","connect","connect","mobile","connect","connect","mobile","mobile","connect","mobile","connect","mobile","connect","mobile","mobile","connect","connect","mobile","connect","connect","mobile","mobile","mobile","mobile","mobile","mobile","connect","mobile","mobile","mobile","mobile","connect","mobile","mobile","connect","connect","mobile","connect","connect","mobile","connect","mobile","connect","connect","mobile","connect","mobile","mobile","connect","connect","connect","mobile ...

# %%
# Effect of delay with previous rental: compare dist of delay and color canceled ended mobile vs connect for successive rentals only
# Plot for absolute deltas of max 4 hours (240 mins)
df_merged_filt = df_merged.copy()
delay_hours = 2
filter_mask = abs(df_merged_filt['delta_checkin_previous_rental']) <= delay_hours*60
filter_mask2 = df_merged_filt.succesive_rental=="yes"
df_merged_filt = df_merged_filt[filter_mask & filter_mask2]


fig = px.box(df_merged_filt, x="state", y="delta_checkin_previous_rental", 
boxmode='group', points='all', facet_col ="checkin_type", 
                labels={
                    "parameter": "Rental status",
                    "delta_checkin_previous_rental": "Delta between checkout and new checkin (mins)",
                    "delta_checkin_previous_rental_problematic": "Time delta category"
                },
                title='Fig11.Delta of time between succesive rental and delay of checkout (max 4 hours displayed)')

fig.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="4b8e2d91-5908-4853-9282-af3172e56807" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b8e2d91-5908-4853-9282-af3172e56807")) {                    Plotly.newPlot(                        "4b8e2d91-5908-4853-9282-af3172e56807",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"checkin_type=mobile<br>state=%{x}<br>Delta between checkout and new checkin (mins)=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa"},"name":"","notched":false,"offsetgroup":"","orientation":"v","showlegend":false,"x":["ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","canceled","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","canceled","canceled","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","end ...

# %%
# Categorize delta of previous rental checkin delay and time between next rental. Use bins
bins = [-np.inf,0, 10, 30, 60, np.inf]
labs = ['problematic' ,'[0-10 mins]', '[10-30 mins]', '[30-60 mins]', '[>60mins]']
df_merged['delta_checkin_previous_rental_problematic'] = pd.cut(df_merged['delta_checkin_previous_rental'], bins = bins, labels=labs)


dfg = df_merged.groupby(['state','delta_checkin_previous_rental_problematic']).size().reset_index(name='counts')
display(dfg)

df_merged_filt = df_merged.copy()
filter_mask = df_merged_filt.succesive_rental=="yes"
df_merged_filt = df_merged_filt[filter_mask]
df_merged_filt.dropna(subset=['delta_checkin_previous_rental_problematic'], inplace=True)

fig = px.histogram(df_merged_filt, x="state", barmode='group',barnorm='percent', color="delta_checkin_previous_rental_problematic",color_discrete_sequence=px.colors.qualitative.D3,
title="Fig12.Category enrichment for time delta of checkout and new checkin for successive rentals", 
labels={
   'delta_checkin_previous_rental_problematic': 'Delta checkout vs new checkin category' 
})
fig.show(renderer='notebook_connected')
# Out:
#       state delta_checkin_previous_rental_problematic  counts
# 0  canceled                               problematic      37
# 1  canceled                               [0-10 mins]       1
# 2  canceled                              [10-30 mins]       9
# 3  canceled                              [30-60 mins]       4
# 4  canceled                                 [>60mins]     154
# 5     ended                               problematic     186
# 6     ended                               [0-10 mins]      41
# 7     ended                              [10-30 mins]      89
# 8     ended                              [30-60 mins]     112
# 9     ended                                 [>60mins]    1081
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="6d6c5382-6f8b-43ba-94f4-f790790254ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d6c5382-6f8b-43ba-94f4-f790790254ce")) {                    Plotly.newPlot(                        "6d6c5382-6f8b-43ba-94f4-f790790254ce",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"Delta checkout vs new checkin category=[>60mins]<br>state=%{x}<br>count (normalized as percent)=%{y}<extra></extra>","legendgroup":"[>60mins]","marker":{"color":"#1F77B4","pattern":{"shape":""}},"name":"[>60mins]","offsetgroup":"[>60mins]","orientation":"v","showlegend":true,"x":["ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","canceled","ended","ended","canceled","ended","canceled","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","canceled","ended","canceled","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","canceled","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","ended","canceled ...

# %%
# Impact of threshold on number of problematic cases and impact on ended rentals not being able to take place

# Prepare new colums
threshold = 45

df_merged['new_delta_checkin_previous_rental'] = threshold - df_merged.previous_ended_rental_checkout_delay
df_merged['new_thresh_problematic_case'] = ['no' if delay<0 else 'yes' for delay in df_merged.new_delta_checkin_previous_rental.tolist()]

# Cases which also become problematic: those that have a lower time delta between checkin and chekout than new threshold
new_thres_problematic = (df_merged['time_delta_with_previous_rental_in_minutes'] < threshold)
df_merged.loc[new_thres_problematic, 'new_thresh_problematic_case'] = 'yes'

# %%
# Count number of problematic cases before and after new threshold
# A new problematic case will be defined in 
df_merged_filt = df_merged.copy()
filter_mask = df_merged_filt.succesive_rental=="yes"
df_merged_filt = df_merged_filt[filter_mask]


dfg = df_merged_filt.delta_checkin_previous_rental_problematic_bool.value_counts()
display(dfg)

problematic_cases = df_merged_filt.delta_checkin_previous_rental_problematic_bool.value_counts()['yes']

dfg_new = df_merged_filt.groupby(['delta_checkin_previous_rental_problematic_bool','new_thresh_problematic_case' ]).size().reset_index(name='counts')
display(dfg_new)

prev_problematic_cases_solved = dfg_new.loc[(dfg_new.delta_checkin_previous_rental_problematic_bool=='yes') & (dfg_new.new_thresh_problematic_case=="no"), 'counts'].tolist()[0]

impacted_ended_rentals_now_problematic = dfg_new.loc[(dfg_new.delta_checkin_previous_rental_problematic_bool=='no') & (dfg_new.new_thresh_problematic_case=="yes"), 'counts'].tolist()[0]


print(sum(dfg_new.counts))
print(f'After using a threshold of {threshold} minutes, there were {prev_problematic_cases_solved} previous problematic cases solved. However, previously ended rentals which would no longer take place with new threshold are: {impacted_ended_rentals_now_problematic}')
# Out:
# no     1623
# yes     218
# Name: delta_checkin_previous_rental_problematic_bool, dtype: int64
#   delta_checkin_previous_rental_problematic_bool new_thresh_problematic_case  \
# 0                                             no                          no
# 1                                             no                         yes
# 2                                            yes                          no
# 3                                            yes                         yes
#
#    counts
# 0     282
# 1    1341
# 2      72
# 3     146
# 1841
# After using a threshold of 45 minutes, there were 72 previous problematic cases solved. However, previously ended rentals which would no longer take place with new threshold are: 1341

# %%
dfg_new_scope = df_merged_filt.groupby(['checkin_type', 'delta_checkin_previous_rental_problematic_bool','new_thresh_problematic_case' ]).size().reset_index(name='counts')
display(dfg_new_scope)

mask_connect = (dfg_new_scope.checkin_type=="connect") & (dfg_new_scope.delta_checkin_previous_rental_problematic_bool=='yes') & (dfg_new_scope.new_thresh_problematic_case=="no")
mask_mobile =  (dfg_new_scope.checkin_type=="mobile") & (dfg_new_scope.delta_checkin_previous_rental_problematic_bool=='yes') & (dfg_new_scope.new_thresh_problematic_case=="no")

mask_connect_2 = (dfg_new_scope.checkin_type=="connect") & (dfg_new_scope.delta_checkin_previous_rental_problematic_bool=='no') & (dfg_new_scope.new_thresh_problematic_case=="yes")
mask_mobile_2 = (dfg_new_scope.checkin_type=="mobile") & (dfg_new_scope.delta_checkin_previous_rental_problematic_bool=='no') & (dfg_new_scope.new_thresh_problematic_case=="yes")


prev_problematic_cases_solved_connect = dfg_new_scope.loc[mask_connect, 'counts'].tolist()[0]
prev_problematic_cases_solved_mobile = dfg_new_scope.loc[mask_mobile, 'counts'].tolist()[0]


impacted_ended_rentals_now_problematic_conn = dfg_new_scope.loc[mask_connect_2, 'counts'].tolist()[0]
impacted_ended_rentals_now_problematic_mob = dfg_new_scope.loc[mask_mobile_2, 'counts'].tolist()[0]

print(f'''After using a threshold of {threshold} minutes, there were {prev_problematic_cases_solved} previous problematic cases solved ({prev_problematic_cases_solved_connect} mobile and {prev_problematic_cases_solved_mobile} connect).
However, previously ended rentals which would no longer take place with new threshold are: {impacted_ended_rentals_now_problematic} ({impacted_ended_rentals_now_problematic_conn}  mobile and {impacted_ended_rentals_now_problematic_mob} connect)''')
# Out:
#   checkin_type delta_checkin_previous_rental_problematic_bool  \
# 0      connect                                             no
# 1      connect                                             no
# 2      connect                                            yes
# 3      connect                                            yes
# 4       mobile                                             no
# 5       mobile                                             no
# 6       mobile                                            yes
# 7       mobile                                            yes
#
#   new_thresh_problematic_case  counts
# 0                          no      88
# 1                         yes     656
# 2                          no      21
# 3                         yes      48
# 4                          no     194
# 5                         yes     685
# 6                          no      51
# 7                         yes      98
# After using a threshold of 45 minutes, there were 72 previous problematic cases solved (21 mobile and 51 connect).
# However, previously ended rentals which would no longer take place with new threshold are: 1341 (656  mobile and 685 connect)

# %%
# Plot a Sankey diagram to better see evolution of cases
# Use documentation to produce plot: https://plotly.com/python/sankey-diagram/#basic-sankey-diagram

import plotly.graph_objects as go


fig = go.Figure(data=[go.Sankey(
    node = dict(
      pad = 15,
      thickness = 20,
      line = dict(color = "black", width = 0.5),
      label = ["not problematic", "problematic", "not problematic", "problematic"],
      color = ["darkblue", 'darkred', "blue", "red"]
    ),
    link = dict(
      source = [0, 0, 1, 1], # indices correspond to labels
      target = [2, 3, 2, 3],
      value = dfg_new.counts.tolist()
  ))])

fig.update_layout(title_text=f"Fig13.Evolution of number of problematic cases due to late check in after new threshold: {threshold} mins", font_size=10)
fig.show(renderer='notebook_connected')
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="58368c0e-254d-4e7c-bcd7-591196b20701" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58368c0e-254d-4e7c-bcd7-591196b20701")) {                    Plotly.newPlot(                        "58368c0e-254d-4e7c-bcd7-591196b20701",                        [{"link":{"source":[0,0,1,1],"target":[2,3,2,3],"value":[282,1341,72,146]},"node":{"color":["darkblue","darkred","blue","red"],"label":["not problematic","problematic","not problematic","problematic"],"line":{"color":"black","width":0.5},"pad":15,"thickness":20},"type":"sankey"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolar":[{"type":"scatterpolar","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"histogram":[{"marker":{"pat ...
#
# v
